# %%
p=int(input("what is a"))
r=int(input("what is r"))
t=int(input("what is t"))
n=int(input("what is n"))
a=p*(1+(r/n))**(n*t)
print("simple interest is",a)
# Out:
# what is a 7
# what is r 9
# what is t 8
# what is n 6
# simple interest is 8.835242138475333e+19

# %%
p=int(input("what is a"))
r=int(input("what is r"))
t=int(input("what is t"))
a=p*(1+(r/100)*t)
print("compound interest is",a)
# Out:
# what is a 6
# what is r 8
# what is t 2
# compound interest is 6.959999999999999

# %%
p=int(input("what is a"))
r=int(input("what is r"))
t=int(input("what is t"))
n=int(input("what is n"))
a=p * ((1 + (r/n))**(n*t) - 1) / (r/n)
print("Annuity plan is",a)
# Out:
# what is a 12
