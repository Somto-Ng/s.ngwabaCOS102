# %%
experience_years = float(input("Enter staff age: "))

if experience_years > 25 and experience_years >= 55:
    atr = 5600000
elif experience_years > 20 and experience_years >= 45:
    atr = 4480000
elif experience_years > 10 and experience_years >= 35:
    atr = 1500000
else:
    atr = 550000

print("The Annual Tax Revenue (ATR) is: ₦", atr)
# Out:
# Enter staff age:  70
# The Annual Tax Revenue (ATR) is: ₦ 5600000
