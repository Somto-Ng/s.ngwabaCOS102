# %%
def student_table():
    # Data from Image III
    g_names = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
    g_ages = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
    g_heights = [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
    g_scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

    b_names = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
    b_ages = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
    b_heights = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
    b_scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

    # Combine data
    all_names = g_names + b_names
    all_ages = g_ages + b_ages
    all_heights = g_heights + b_heights
    all_scores = g_scores + b_scores

    print(f"{'Name':<12} | {'Age':<5} | {'Height':<7} | {'Score':<5}")
    print("-" * 40)
    for i in range(len(all_names)):
        print(f"{all_names[i]:<12} | {all_ages[i]:<5} | {all_heights[i]:<7} | {all_scores[i]:<5}")
